# %%
import sys
import os

# Thêm đường dẫn của thư mục gốc vào sys.path
project_root = "/Users/qcinsced/Documents/GitHub/awesome-ai-models"  # Chỉnh lại nếu cần
sys.path.append(project_root)
print(os.listdir(os.path.join(project_root, "models/machine_learning")))
# Out:
# ['test', '__pycache__', 'softmax_regression.py', 'logistic_regression.py', 'linear_regression.py']

# %%
# Test Linear Regression Implementation

# Import libraries
import numpy as np
import matplotlib.pyplot as plt
from models.machine_learning.linear_regression import LinearRegression

# Generate synthetic data
np.random.seed(42)
X = np.random.rand(100, 1) * 10  # 100 samples, single feature
y = 2.5 * X.flatten() + 5 + np.random.randn(100) * 2  # y = 2.5x + 5 + noise

# Visualize the data
plt.scatter(X, y, color="blue", label="True Data")
plt.xlabel("X")
plt.ylabel("y")
plt.title("Synthetic Data for Linear Regression")
plt.legend()
plt.show()

# Initialize and train Linear Regression model
model = LinearRegression(learning_rate=0.01, epochs=1000)
model.fit(X, y)

# Predict values
y_pred = model.predict(X)

# Visualize results
plt.scatter(X, y, color="blue", label="True Data")
plt.plot(X, y_pred, color="red", label="Predicted Line")
plt.xlabel("X")
plt.ylabel("y")
plt.title("Linear Regression - True vs Predicted")
plt.legend()
plt.show()

# Evaluate model
mse = np.mean((y - y_pred) ** 2)
print(f"Mean Squared Error: {mse:.4f}")

# Test predictions on new data
new_data = np.array([[1.5], [3.5], [7.5]])
new_predictions = model.predict(new_data)
print(f"Predictions for new data {new_data.flatten()}: {new_predictions}")
# Out:
# Epoch 0, Loss: 334.6729594760979
# Epoch 100, Loss: 7.20702630880883
# Epoch 200, Loss: 5.510510491791774
# Epoch 300, Loss: 4.5370269443500515
# Epoch 400, Loss: 3.9784290181568256
# Epoch 500, Loss: 3.657898030275851
# Epoch 600, Loss: 3.4739730470735073
# Epoch 700, Loss: 3.368434422962244
# Epoch 800, Loss: 3.307874943845452
# Epoch 900, Loss: 3.2731251018631378
# Mean Squared Error: 3.2532
# Predictions for new data [1.5 3.5 7.5]: [ 8.80563971 13.71626046 23.53750195]
